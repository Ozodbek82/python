# %%
# case1  hafta kunlari
son=int(input("(1-7)sonni kiriting="))
if son==1:
    print("dushanba")
elif son==2:
    print("seshanba")
elif son==3:
    print("chorshanba")
elif son==4:
    print("payshanba")
elif son==5:
    print("juma")
elif son==6:
    print("shanba")
elif son==7:
    print("yakshanba")
else:
    print("noto`g`ri son kiritildi")
# Out:
# noto`g`ri son kiritildi

# %%
# case2 baholar
son=int(input("(1-5)sonni kiriting="))
if son==1:
    print("yomon")
elif son==2:
    print("qoniqarsiz")
elif son==3:
    print("qoniqarli")
elif son==4:
    print("yaxshi")
elif son==5:
    print("a`lo")
else:
    print("xato")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [2], in <module>
#       1 # case2 baholar
# ----> 2 son=int(input("(1-5)sonni kiriting="))
#       3 if son==1:
#       4     print("yomon")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# case3   mavsumlar
son=int(input("(1-12)oyni kiriting="))
if 2<son<6:
    print("bahor")
elif 5<son<9:
    print("yoz")
elif 8<son<12:
    print("kuz")
elif son==12 or 0<son<3:
    print("qish")
else:
    print("oy noto`g`ri")
# Out:
# (1-12)oyni kiriting=3
# bahor

# %%
# case4 oyni 30 yoki 31 ligi
oy=int(input("(1-12)oyni kiriting="))
if oy==2:
    print(28)
elif oy==1 or oy==3 or oy==5 or oy==7 or oy==8 or oy==10 or oy==12:
    print(31)
elif oy==4 or oy==6 or oy==9 or oy==11:
    print(30)
else:
    print("oy noto`g`ri kiritildi=",oy)
# Out:
# (1-12)oyni kiriting=8
# 31

# %%
# case5
a=float(input("A soni="))
b=float(input("B soni="))
n=int(input("arifmetik amalni kiriting(1-qo`shish,2-ayirish,3-ko`paytirish,4-bo`lish)="))
if not(1<=n<=4):
    print("noto`g`ri amal kiritildi")
elif n==1:
    print(a,"+",b,"=",a+b)
elif n==2:
    print(a,"-",b,"=",a-b)
elif n==3:
    print(a,"*",b,"=",a*b)
elif n==4 and b!=0:
    print(a,"/",b,"=",a/b)
else:
    print("xato",a,"/",b)
# Out:
# A soni=7
# B soni=-8
# arifmetik amalni kiriting(1-qo`shish,2-ayirish,3-ko`paytirish,4-bo`lish)=5
# noto`g`ri amal kiritildi

# %%
# case6
a=int(input("o`lchovni kiriting(1-dm,2-km,3-metr,4-mm,5-sm)="))
b=float(input("uzunlikni kiriting="))
if a==1:
    print(b/10)
elif a==2:
    print(b*1000)
elif a==3:
    print(b)
elif a==4:
    print(b/1000)
elif a==5:
    print(b/100)
else:
    print("xato")
# Out:
# o`lchovni kiriting(1-dm,2-km,3-metr,4-mm,5-sm)=6
# uzunlikni kiriting=1422
# xato

# %%
# case7 
a=int(input("birlikni kiriting.(1-kg,2-mg,3-g,4-tn,5-sntr)="))
b=float(input("qiymat="))
if a==1:
    print(b)
elif a==2:
    print(b/1000000)
elif a==3:
    print(b/1000)
elif a==4:
    print(b*1000)
elif a==5:
    print(b*100)
else:
    print("xato")
# Out:
# birlikni kiriting.(1-kg,2-mg,3-g,4-tn,5-sntr)=3
# qiymat=100
# 0.1

# %%
# case8 berilgan kundan oldingi kunni
kun=int(input("kunni kiriting="))
oy=int(input("oyni kiriting="))
kun=kun-1
if kun!=0:
    print(kun,oy)
oy=oy-1
if kun==0 and oy==0:
    print(31,12)
elif kun==0 and oy==2:
    print(28,oy)
elif kun==0 and (oy==1 or oy==3 or oy==5 or oy==7 or oy==8 or oy==10 or oy==12):
    print(31,oy)
elif kun==0 and (oy==4 or oy==6 or oy==9 or oy==11):
    print(30,oy)
# Out:
# kunni kiriting=1
# oyni kiriting=3
# 28 2

# %%
# case 9 kunni keyingisini
kun=int(input("kunni kiriting="))
oy=int(input("oyni kiriting="))
if kun==31 and oy==12:
    print(1,1)
elif kun==31 and (oy==1 or oy==3 or oy==5 or oy==7 or oy==8 or oy==10):
    print(1,oy+1)
elif kun==30 and (oy==4 or oy==6 or oy==9 or oy==11):
    print(1,oy+1)
elif kun==28 and oy==2:
    print(1,3)
else:
    print(kun+1,oy)
# Out:
# kunni kiriting=31
# oyni kiriting=1
# 1 2

# %%
# case 10 yo`nalish
#s-shimol j-janub q-sharq g-g`arb
# 0 davom 1 onga 2 chapga 
#y,k,c=0,0,0
y=input("Y robotning hozirgi turgan yo`nalishi=")
k=int(input("K komanda="))
if y=="s":
    if k==0:
        c="shimol"
    elif k==1:
        c="sharq"
    elif k==2:
        c="g`arb"
if y=="q":
    if k==0:
        c="sharq"
    elif k==1:
        c="janub"
    elif k==2:
        c="shimol"
if y=="g":
    if k==0:
        c="g`arb"
    elif k==1:
        c="shimol"
    elif k==2:
        c="janub"
if y=="j":
    if k==0:
        c="janub"
    elif k==1:
        c="g`arb"
    elif k==2:
        c="sharq"
print(c)
# Out:
# Y robotning hozirgi turgan yo`nalishi=s
# K komanda=1
# sharq

# %%
# case 11 o- o`ngga 1- chapga 2- 180 gradusga
c=input("C lokatorni hozirgi turgan yo`nalishi=")
k1=int(input("K1 komanda="))
k2=int(input("K2 komanda="))
if c=="s":
    if k1+k2==1 or k1+k2==4:
        y="shimol"
    elif k1+k2==0 or (k1+k2==2 and k1*k2==1):
        y="janub"
    elif k1+k2==3:
        y="sharq"
    elif k1+k2==2 and k1*k2==0:
        y="g`arb"
if c=="q":
    if k1+k2==1 or k1+k2==4:
        y="sharq"
    elif k1+k2==0 or (k1+k2==2 and k1*k2==1):
        y="g`arb"
    elif k1+k2==3:
        y="janub"
    elif k1+k2==2 and k1*k2==0:
        y="shimol"
if c=="g":
    if k1+k2==1 or k1+k2==4:
        y="janub"
    elif k1+k2==0 or (k1+k2==2 and k1*k2==1):
        y="sharq"
    elif k1+k2==3:
        y="shimol"
    elif k1+k2==2 and k1*k2==0:
        y="sharq" 
if c=="j":
    if k1+k2==1 or k1+k2==4:
        y="janub"
    elif k1+k2==0 or (k1+k2==2 and k1*k2==1):
        y="shimol"
    elif k1+k2==3:
        y="g`arb"
    elif k1+k2==2 and k1*k2==0:
        y="sharq"
print(y)
# Out:
# C lokatorni hozirgi turgan yo`nalishi=q
# K1 komanda=1
# K2 komanda=1
# g`arb

# %%
# case 12 doira
a=input("R-radius,D-diametr,L-uzunlik,S-yuzadan birini kiriting=")
b=float(input("qiymatini kiriting="))
PI=3.14
if a=="R":
    print("diametri=",2*b,"uzunligi=",2*PI*b,"yuzasi=",PI*b*b)
elif a=="D":
    print("radiusi=",b/2,"uzunligi=",PI*b,"yuzasi=",(b/2)**2*PI)
elif a=="L":
    print("radiusi=",b/(2*PI),"diametri=",b/PI,"yuzasi=",(b**2)/(4*PI))
elif a=="S":
    print("radiusi=",(b/PI)**(1/2),"diametri=",((b/PI)**(1/2))*2,"uzunligi=",2*PI*((b/PI)**(1/2)))
# Out:
# R-radius,D-diametr,L-uzunlik,S-yuzadan birini kiriting=S
# qiymatini kiriting=28.26
# radiusi= 3.0 diametri= 6.0 uzunligi= 18.84

# %%
# case 13
r=input("a,c,h,s dan birini kiriting=")
q=float(input("qiymatini kiriting="))
if r=="a":
    c=q*(2**(1/2))
    h=c/2
    s=c*h/2
    print("c=",c,"h=",h,"s=",s)
elif r=="c":
    a=q/(2**(1/2))
    h=q/2
    s=q*h/2
    print("a=",a,"h=",h,"s=",s)
elif r=="h":
    c=2*q
    a=c/(2**(1/2))
    s=q**2
    print("a=",a,"c=",c,"s=",s)
elif r=="s":
    h=q**(1/2)
    c=2*h
    a=c/(2**(1/2))
    print("a=",a,"c=",c,"h=",h)
else: print("xato")
# Out:
# a,c,h,s dan birini kiriting=a
# qiymatini kiriting=5.65685424949238
# c= 8.0 h= 4.0 s= 16.0

# %%
# case 14 aylana ichidagi uchburchak
# a=4  r1= 1.1547005383792515 r2= 2.309401076758503 s= 6.928203230275509
r=input("a,r1,r2,s dan birini kiriting=")
q=float(input("qiymatini kiriting="))
if r=="a":
    r1=q*3**(1/2)/6
    r2=2*r1
    s=q**2*3**(1/2)/4
    print("r1=",r1,"r2=",r2,"s=",s)
elif r=="r1":
    a=2*(3**(1/2))*q
    r2=2*q
    s=3*(3**(1/2))*q**2
    print("a=",a,"r2",r2,"s=",s)
elif r=="r2":
    r1=q/2
    a=2*(3**(1/2))*r1
    s=3*(3**(1/2))*r1**2
    print("a=",a,"r1=",r1,"s=",s)
elif r=="s":
    a=(4*q/(3**(1/2)))**(1/2)
    r1=a*3**(1/2)/6
    r2=2*r1
    print("a=",a,"r1=",r1,"r2=",r2)
else: print("xato")
# Out:
# a,r1,r2,s dan birini kiriting=s
# qiymatini kiriting=6.928203230275509
# a= 4.0 r1= 1.1547005383792515 r2= 2.309401076758503

# %%
# case 15 karta 
n=int(input("N karta qiymati(6<=N<=14)"))
m=int(input("M karta turini(1<=M<=4)"))
if n==6:
    n1="olti"
elif n==7:
    n1="yetti"
elif n==8:
    n1="sakkiz"
elif n==9:
    n1="to`qqiz"
elif n==10:
    n1="o`n"
elif n==11:
    n1="valet"
elif n==12:
    n1="dama"
elif n==13:
    n1="qirol"
elif n==14:
    n1="tuz"
if m==1:
    m1="g`isht"
elif m==2:
    m1="olma"
elif m==3:
    m1="chillak"
elif m==4:
    m1="qarg`a"
print(n1,m1)
# Out:
# N karta qiymati(6<=N<=14)6
# M karta turini(1<=M<=4)1
# olti g`isht

# %%
# case 16
n=int(input("sonni kiriting="))
a1="bir"
a2="ikki"
a3="uch"
a4="to`rt"
a5="besh"
a6="olti"
a7="yetti"
a8="sakkiz"
a9="to`qqiz"
a10="o`n"
a20="yigirma"
a30="o`ttiz"
a40="qirq"
a50="ellik"
a60="oltmish"
a70="yetmish"
a80="sakson"
a90="to`qson"
onlik=n//10
birlik=n%10
b,o="",""
if birlik==1:
    b=a1
elif birlik==2:
    b=a2
elif birlik==2:
    b=a2
elif birlik==3:
    b=a3
elif birlik==4:
    b=a4
elif birlik==5:
    b=a5
elif birlik==6:
    b=a6
elif birlik==7:
    b=a7
elif birlik==8:
    b=a8
elif birlik==9:
    b=a9
if onlik==1:
    o=a10
elif onlik==2:
    o=a20
elif onlik==3:
    o=a30
elif onlik==4:
    o=a40
elif onlik==5:
    o=a50
elif onlik==6:
    o=a60
elif onlik==7:
    o=a70
elif onlik==8:
    o=a80
elif onlik==9:
    o=a90
print(o,b,"yosh")
# Out:
# N ni kiriting=1
#  bir yosh

# %%
# case 17
n=int(input("sonni kiriting="))
a1="bit"
a2="ikki"
a3="uch"
a4="to`rt"
a5="besh"
a6="olti"
a7="yetti"
a8="sakkiz"
a9="to`qqiz"
a10="o`n"
a20="yigirma"
a30="o`ttiz"
a40="qirq"
a50="ellik"
a60="oltmish"
a70="yetmish"
a80="sakson"
a90="to`qson"
onlik=n//10
birlik=n%10
b,o="",""
if birlik==1:
    b=a1
elif birlik==2:
    b=a2
elif birlik==2:
    b=a2
elif birlik==3:
    b=a3
elif birlik==4:
    b=a4
elif birlik==5:
    b=a5
elif birlik==6:
    b=a6
elif birlik==7:
    b=a7
elif birlik==8:
    b=a8
elif birlik==9:
    b=a9
if onlik==1:
    o=a10
elif onlik==2:
    o=a20
elif onlik==3:
    o=a30
elif onlik==4:
    o=a40
elif onlik==5:
    o=a50
elif onlik==6:
    o=a60
elif onlik==7:
    o=a70
elif onlik==8:
    o=a80
elif onlik==9:
    o=a90
print(o,b+"ta masala")
# Out:
# sonni kiriting=1
#  bitta masala

# %%
# case 18 100-999
n=int(input("N ni kiriting="))
a1="bir"
a2="ikki"
a3="uch"
a4="to`rt"
a5="besh"
a6="olti"
a7="yetti"
a8="sakkiz"
a9="to`qqiz"
a10="o`n"
a20="yigirma"
a30="o`ttiz"
a40="qirq"
a50="ellik"
a60="oltmish"
a70="yetmish"
a80="sakson"
a90="to`qson"
onlik=n//10%10
birlik=n%10
yuzlik=n//100
b,o="",""
if birlik==1:
    b=a1
elif birlik==2:
    b=a2
elif birlik==2:
    b=a2
elif birlik==3:
    b=a3
elif birlik==4:
    b=a4
elif birlik==5:
    b=a5
elif birlik==6:
    b=a6
elif birlik==7:
    b=a7
elif birlik==8:
    b=a8
elif birlik==9:
    b=a9
#onlik
if onlik==1:
    o=a10
elif onlik==2:
    o=a20
elif onlik==3:
    o=a30
elif onlik==4:
    o=a40
elif onlik==5:
    o=a50
elif onlik==6:
    o=a60
elif onlik==7:
    o=a70
elif onlik==8:
    o=a80
elif onlik==9:
    o=a90
#yuzlik
if yuzlik==0:
    y=""
elif yuzlik==1:
    y=a1+" yuz"
elif yuzlik==2:
    y=a2+" yuz"
elif yuzlik==3:
    y=a3+" yuz"
elif yuzlik==4:
    y=a4+" yuz"
elif yuzlik==5:
    y=a5+" yuz"
elif yuzlik==6:
    y=a6+" yuz"
elif yuzlik==7:
    y=a7+" yuz"
elif yuzlik==8:
    y=a8+" yuz"
elif yuzlik==9:
    y=a9+" yuz"
print(y,o,b)
# Out:
# N ni kiriting=999
# to`qqiz yuz to`qson to`qqiz

# %%
#case 19 
n=int(input("yilni kiriting="))
c=n%10; a=(n+8)%12
if c==0 or c==1:
    rang="oq"
elif c==2 or c==3:
    rang="qora"
elif c==3 or c==4:
    rang="yashil"
elif c==5 or c==6:
    rang="qizil"
else:
    rang="sariq"
if a==0:
    an="sichqon"
elif a==1:
    an="sigir"
elif a==2:
    an="yo`lbars"
elif a==3:
    an="quyon"
elif a==4:
    an="ajdar"
elif a==5:
    an="ilon"
elif a==6:
    an="ot"
elif a==7:
    an="qo`y"
elif a==8:
    an="maymun"
elif a==9:
    an="tovuq"
elif a==10:
    an="it"
else:
    an="to`ngiz"
print(rang,an,"yili")
# Out:
# yilni kiriting=2022
# 2022 - oq yo`lbars yili

# %%
# case 20
kun=int(input("kunni kiriting="))
oy=int(input("oyni kiriting="))
if oy==1 and 20<=kun<=31 or 1<=kun<=18 and oy==2:
    print("Qovg`a")
elif oy==2 and 19<=kun<=28 or 1<=kun<=20 and oy==3:
    print("Baliq")
elif oy==3 and 21<=kun<=31 or 1<=kun<=19 and oy==4:
    print("Qo`y")
elif oy==4 and 20<=kun<=30 or 1<=kun<=20 and oy==5:
    print("Buzoq")
elif oy==5 and 21<=kun<=31 or 1<=kun<=21 and oy==6:
    print("Egizaklar")
elif oy==6 and 22<=kun<=30 or 1<=kun<=22 and oy==7:
    print("Qisqichbaqa")
elif oy==7 and 23<=kun<=31 or 1<=kun<=22 and oy==8:
    print("Arslon")
elif oy==8 and 23<=kun<=31 or 1<=kun<=22 and oy==9:
    print("Parizod")
elif oy==9 and 23<=kun<=30 or 1<=kun<=22 and oy==10:
    print("Tarozi")
elif oy==10 and 23<=kun<=31 or 1<=kun<=22 and oy==11:
    print("Chayon")
elif oy==11 and 23<=kun<=30 or 1<=kun<=21 and oy==12:
    print("O`qotar")
elif oy==12 and 22<=kun<=31 or 1<=kun<=19 and oy==1:
    print("Echki")
# Out:
# kunni kiriting=18
# oyni kiriting=4
# Qo`y

# %%
#uyga vazifa 1-999_999_999
n=int(input("N ni kiriting="))
a1="bir"
a2="ikki"
a3="uch"
a4="to`rt"
a5="besh"
a6="olti"
a7="yetti"
a8="sakkiz"
a9="to`qqiz"
a10="o`n"
a20="yigirma"
a30="o`ttiz"
a40="qirq"
a50="ellik"
a60="oltmish"
a70="yetmish"
a80="sakson"
a90="to`qson"
onlik=n%100//10
birlik=n%10
yuzlik=n%1000//100
ming=n%10000//1000
on_ming=n%100_000//10000
yuz_ming=n%1000_000//100_000
million=n%10_000_000//1000_000
on_million=n%100_000_000//10_000_000
yuz_million=n%1000_000_000//100_000_000
birlik,onlik="",""
if birlik==1:
    birlik=a1
elif birlik==2:
    birlik=a2
elif birlik==2:
    birlik=a2
elif birlik==3:
    birlik=a3
elif birlik==4:
    birlik=a4
elif birlik==5:
    birlik=a5
elif birlik==6:
    birlik=a6
elif birlik==7:
    birlik=a7
elif birlik==8:
    birlik=a8
elif birlik==9:
    birlik=a9
#onlik
if onlik==1:
    onlik=a10
elif onlik==2:
    onlik=a20
elif onlik==3:
    onlik=a30
elif onlik==4:
    onlik=a40
elif onlik==5:
    onlik=a50
elif onlik==6:
    onlik=a60
elif onlik==7:
    onlik=a70
elif onlik==8:
    onlik=a80
elif onlik==9:
    onlik=a90
#yuzlik
if yuzlik==0:
    yuzlik=""
elif yuzlik==1:
    yuzlik=a1+" yuz"
elif yuzlik==2:
    yuzlik=a2+" yuz"
elif yuzlik==3:
    yuzlik=a3+" yuz"
elif yuzlik==4:
    yuzlik=a4+" yuz"
elif yuzlik==5:
    yuzlik=a5+" yuz"
elif yuzlik==6:
    yuzlik=a6+" yuz"
elif yuzlik==7:
    yuzlik=a7+" yuz"
elif yuzlik==8:
    yuzlik=a8+" yuz"
elif yuzlik==9:
    yuzlik=a9+" yuz"
#minglik
if ming==0:
    ming="ming"
elif ming==1:
    ming=a1+" ming"
elif ming==2:
    ming=a2+" ming"
elif ming==3:
    ming=a3+" ming"
elif ming==4:
    ming=a4+" ming"
elif ming==5:
    ming=a5+" ming"
elif ming==6:
    ming=a6+" ming"
elif ming==7:
    ming=a7+" ming"
elif ming==8:
    ming=a8+" ming"
elif ming==9:
    ming=a9+" ming"
#on_ming
if on_ming==0:
    on_ming=""
if on_ming==1:
    on_ming=a10
elif on_ming==2:
    on_ming=a20
elif on_ming==3:
    on_ming=a30
elif on_ming==4:
    on_ming=a40
elif on_ming==5:
    on_ming=a50
elif on_ming==6:
    on_ming=a60
elif on_ming==7:
    on_ming=a70
elif on_ming==8:
    on_ming=a80
elif on_ming==9:
    on_ming=a90
#yuz_ming
if yuz_ming==0:
    yuz_ming=""
elif yuz_ming==1:
    yuz_ming=a1+" yuz"
elif yuz_ming==2:
    yuz_ming=a2+" yuz"
elif yuz_ming==3:
    yuz_ming=a3+" yuz"
elif yuz_ming==4:
    yuz_ming=a4+" yuz"
elif yuz_ming==5:
    yuz_ming=a5+" yuz"
elif yuz_ming==6:
    yuz_ming=a6+" yuz"
elif yuz_ming==7:
    yuz_ming=a7+" yuz"
elif yuz_ming==8:
    yuz_ming=a8+" yuz"
elif yuz_ming==9:
    yuz_ming=a9+" yuz"
# million
if million==0:
    million=""
elif million==1:
    million=a1+" million"
elif million==2:
    million=a2+" million"
elif million==2:
    million=a2+" million"
elif million==3:
    million=a3+" million"
elif million==4:
    million=a4+" million"
elif million==5:
    million=a5+" million"
elif million==6:
    million=a6+" million"
elif million==7:
    million=a7+" million"
elif million==8:
    million=a8+" million"
elif million==9:
    million=a9+" million"
#on_million
if on_million==0:
    on_million=""
elif on_million==1:
    on_million=a10
elif on_million==2:
    on_million=a20
elif on_million==3:
    on_million=a30
elif on_million==4:
    on_million=a40
elif on_million==5:
    on_million=a50
elif on_million==6:
    on_million=a60
elif on_million==7:
    on_million=a70
elif on_million==8:
    on_million=a80
elif on_million==9:
    on_million=a90
#yuz_million
if yuz_million==0:
    yuz_million=""
elif yuz_million==1:
    yuz_million=a1+" yuz"
elif yuz_million==2:
    yuz_million=a2+" yuz"
elif yuz_million==3:
    yuz_million=a3+" yuz"
elif yuz_million==4:
    yuz_million=a4+" yuz"
elif yuz_million==5:
    yuz_million=a5+" yuz"
elif yuz_million==6:
    yuz_million=a6+" yuz"
elif yuz_million==7:
    yuz_million=a7+" yuz"
elif yuz_million==8:
    yuz_million=a8+" yuz"
elif yuz_million==9:
    yuz_million=a9+" yuz"    
print(yuz_million,on_million,million,yuz_ming,on_ming,ming,yuzlik,onlik,birlik)
# Out:
#   bir million bir yuz  ming

# %%
# bo`lish amali faqat qo`shish va ayirish bilan
# bo`linuvchi= a
# bo`luvchi= b
# natija = c
# qoldiq = r
# oraliq son = s
c=0;k=0;i_a=1;i_b=1
a=float(input("bo`linuvchini kiriting="))
b=float(input("bo`luvchini kiriting="))
if a<0:
    i_a=(-1)
    a=abs(a)
if b<0:
    i_b=(-1)
    b=abs(b)

if a>b:
    while a>b:
        a=a-b
        c=c+1
    print(i_a*i_b*c,end=".")        
    while k<=15:
        i=0;s=0
        while i<10:
            s=s+a 
            i=i+1       
        l=0
        while s>=b:
            s=s-b
            l+=1
        print(l,end="")
        if s==0:
            k=16
        k=k+1;a=s;
elif a<b:
    if i_a*i_b==-1:
        ishora="-0"
    else:
        ishora="0"
    print(ishora,end=".")        
    while k<=15:
        i=0;s=0
        while i<10:
            s=s+a 
            i=i+1        
        l=0
        while s>=b:
            s=s-b
            l+=1
        print(l,end="")
        if s==0:
            k=16
        k=k+1;a=s;
elif a==b:
    print(1)
# Out:
# bo`linuvchini kiriting=1100000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <module>
#       7 c=0;k=0;i_a=1;i_b=1
#       8 a=float(input("bo`linuvchini kiriting="))
# ----> 9 b=float(input("bo`luvchini kiriting="))
#      10 if a<0:
#      11     i_a=(-1)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1044, in Kernel.raw_input(self, prompt)
#    1040 if not self._allow_stdin:
#    1041     raise StdinNotImplementedError(
#    1042         "raw_input was called, but this frontend does not support input requests."
#    1043     )
# -> 1044 return self._input_request(
#    1045     str(prompt),
#    1046     self._parent_ident["shell"],
#    1047     self.get_parent("shell"),
#    1048     password=False,
#    1049 )
#
# ...

# %%
# case8 berilgan kundan oldingi kunni
kun=int(input("kunni kiriting="))
oy=int(input("oyni kiriting="))
yil=int(input("yilni kiriting="))
kun=kun-1
if kun!=0:
    print(kun,oy,yil)
oy=oy-1
if kun==0 and oy==0:
    print(31,12,yil-1)
elif kun==0 and oy==2 and yil%4!=0:
    print(28,oy,yil)
elif kun==0 and oy==2 and yil%4==0:
    print(29,oy,yil)
elif kun==0 and (oy==1 or oy==3 or oy==5 or oy==7 or oy==8 or oy==10 or oy==12):
    print(31,oy,yil)
elif kun==0 and (oy==4 or oy==6 or oy==9 or oy==11):
    print(30,oy,yil)

# %%
#uyga vazifa berigan kunni ertasini topish

d = int(input('d = '))
m = int(input('m = '))
y = int(input('y = '))

kabisa = False
if y%4==0:
    kabisa=True
if y%100==0 and y%400!=0:
    kabisa=False
if m==1 or m==3 or m==5 or m==7 or m==8 or m==10 :
    if d == 31:
        d = 2
        m = m + 1
    elif d==30:
        d = 1
        m=m+1
        
elif m == 2:
    if d == 28 + kabisa:
        d = 2
        m = 3
    elif d==27+kabisa:
        d=1
        m=3
else:
    if d == 30:
        d = 2
        m = m + 1
    elif d==29:
        d=1
        m=m+1
    elif m == 12 and d==30:
        m = 1
        d = 1
        y = y + 1
    elif m == 12 and d==31:
        m = 1
        d = 2
        y = y + 1
    else:
        d=d+2
print(d,m,y,sep='-')
# Out:
# d = 27
# m = 2
# y = 2022
# 1-3-2022
