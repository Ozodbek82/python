# %%
uyga vazifa 1-999_999_999
n=int(input("N ni kiriting="))
a1="bir"
a2="ikki"
a3="uch"
a4="to`rt"
a5="besh"
a6="olti"
a7="yetti"
a8="sakkiz"
a9="to`qqiz"
a10="o`n"
a20="yigirma"
a30="o`ttiz"
a40="qirq"
a50="ellik"
a60="oltmish"
a70="yetmish"
a80="sakson"
a90="to`qson"
onlik=n%100//10
birlik=n%10
yuzlik=n%1000//100
ming=n%10000//1000
on_ming=n%100_000//10000
yuz_ming=n%1000_000//100_000
million=n%10_000_000//1000_000
on_million=n%100_000_000//10_000_000
yuz_million=n%1000_000_000//100_000_000
birlik,onlik="",""
if birlik==1:
    birlik=a1
elif birlik==2:
    birlik=a2
elif birlik==2:
    birlik=a2
elif birlik==3:
    birlik=a3
elif birlik==4:
    birlik=a4
elif birlik==5:
    birlik=a5
elif birlik==6:
    birlik=a6
elif birlik==7:
    birlik=a7
elif birlik==8:
    birlik=a8
elif birlik==9:
    birlik=a9
#onlik
if onlik==1:
    onlik=a10
elif onlik==2:
    onlik=a20
elif onlik==3:
    onlik=a30
elif onlik==4:
    onlik=a40
elif onlik==5:
    onlik=a50
elif onlik==6:
    onlik=a60
elif onlik==7:
    onlik=a70
elif onlik==8:
    onlik=a80
elif onlik==9:
    onlik=a90
#yuzlik
if yuzlik==0:
    yuzlik=""
elif yuzlik==1:
    yuzlik=a1+" yuz"
elif yuzlik==2:
    yuzlik=a2+" yuz"
elif yuzlik==3:
    yuzlik=a3+" yuz"
elif yuzlik==4:
    yuzlik=a4+" yuz"
elif yuzlik==5:
    yuzlik=a5+" yuz"
elif yuzlik==6:
    yuzlik=a6+" yuz"
elif yuzlik==7:
    yuzlik=a7+" yuz"
elif yuzlik==8:
    yuzlik=a8+" yuz"
elif yuzlik==9:
    yuzlik=a9+" yuz"
#minglik
if ming==0:
    ming="ming"
elif ming==1:
    ming=a1+" ming"
elif ming==2:
    ming=a2+" ming"
elif ming==3:
    ming=a3+" ming"
elif ming==4:
    ming=a4+" ming"
elif ming==5:
    ming=a5+" ming"
elif ming==6:
    ming=a6+" ming"
elif ming==7:
    ming=a7+" ming"
elif ming==8:
    ming=a8+" ming"
elif ming==9:
    ming=a9+" ming"
#on_ming
if on_ming==1:
    on_ming=a10
elif on_ming==2:
    on_ming=a20
elif on_ming==3:
    on_ming=a30
elif on_ming==4:
    on_ming=a40
elif on_ming==5:
    on_ming=a50
elif on_ming==6:
    on_ming=a60
elif on_ming==7:
    on_ming=a70
elif on_ming==8:
    on_ming=a80
elif on_ming==9:
    on_ming=a90
#yuz_ming
if yuz_ming==0:
    yuz_ming=""
elif yuz_ming==1:
    yuz_ming=a1+" yuz"
elif yuz_ming==2:
    yuz_ming=a2+" yuz"
elif yuz_ming==3:
    yuz_ming=a3+" yuz"
elif yuz_ming==4:
    yuz_ming=a4+" yuz"
elif yuz_ming==5:
    yuz_ming=a5+" yuz"
elif yuz_ming==6:
    yuz_ming=a6+" yuz"
elif yuz_ming==7:
    yuz_ming=a7+" yuz"
elif yuz_ming==8:
    yuz_ming=a8+" yuz"
elif yuz_ming==9:
    yuz_ming=a9+" yuz"
# million
if million==1:
    million=a1+" million"
elif million==2:
    million=a2+" million"
elif million==2:
    million=a2+" million"
elif million==3:
    million=a3+" million"
elif million==4:
    million=a4+" million"
elif million==5:
    million=a5+" million"
elif million==6:
    million=a6+" million"
elif million==7:
    million=a7+" million"
elif million==8:
    million=a8+" million"
elif million==9:
    million=a9+" million"
#on_million
if on_million==1:
    on_million=a10
elif on_million==2:
    on_million=a20
elif on_million==3:
    on_million=a30
elif on_million==4:
    on_million=a40
elif on_million==5:
    on_million=a50
elif on_million==6:
    on_million=a60
elif on_million==7:
    on_million=a70
elif on_million==8:
    on_million=a80
elif on_million==9:
    on_million=a90
#yuz_million
if yuz_million==0:
    yuz_million=""
elif yuz_million==1:
    yuz_million=a1+" yuz"
elif yuz_million==2:
    yuz_million=a2+" yuz"
elif yuz_million==3:
    yuz_million=a3+" yuz"
elif yuz_million==4:
    yuz_million=a4+" yuz"
elif yuz_million==5:
    yuz_million=a5+" yuz"
elif yuz_million==6:
    yuz_million=a6+" yuz"
elif yuz_million==7:
    yuz_million=a7+" yuz"
elif yuz_million==8:
    yuz_million=a8+" yuz"
elif yuz_million==9:
    yuz_million=a9+" yuz"    
print(yuz_million,on_million,million,yuz_ming,on_ming,ming,yuzlik,onlik,birlik)

# %%
# bo`lish amali faqat qo`shish va ayirish bila
c=0;k=0;i_a=1;i_b=1;butun=0
a=float(input("bo`linuvchini kiriting="))
b=float(input("bo`luvchini kiriting="))
print(a/b)
if a<0:
    i_a="m"
    a=abs(a)
if b<0:
    i_b="m"
    b=abs(b)
if a>b:
    while a>=b:
        a=a-b
        c=c+1
    butun=c   
if a<b:    
    raz=0
    while raz<19:
        i=0;s=0
        while i<10:
            s=s+a 
            i=i+1        
        l1=0
        while s>=b:
            s=s-b
            l1+=1
        raz+=1;s1=0;i=0
        if raz==1 :            
            while i<l1:
                s1+=0.1
                i+=1
            num=s1            
        elif raz==2:
            while i<l1:
                s1+=0.01
                i+=1
            num1=s1
        elif raz==3:
            while i<l1:
                s1+=0.001
                i+=1
            num2=s1
        elif raz==4:
            while i<l1:
                s1+=0.0001
                i+=1
            num3=s1
        elif raz==5:
            while i<l1:
                s1+=0.00001
                i+=1
            num4=s1
        elif raz==6:
            while i<l1:
                s1+=0.000001
                i+=1
            num5=s1
        elif raz==7:
            while i<l1:
                s1+=0.0000001
                i+=1
            num6=s1
        elif raz==8:
            while i<l1:
                s1+=0.00000001
                i+=1
            num7=s1
        elif raz==9:
            while i<l1:
                s1+=0.000000001
                i+=1
            num8=s1
        elif raz==10:
            while i<l1:
                s1+=0.0000000001
                i+=1
            num9=s1
        elif raz==11:
            while i<l1:
                s1+=0.00000000001
                i+=1
            num10=s1
        elif raz==12:
            while i<l1:
                s1+=0.000000000001
                i+=1
            num11=s1
        elif raz==13:
            while i<l1:
                s1+=0.0000000000001
                i+=1
            num12=s1   
        elif raz==14:
            while i<l1:
                s1+=0.00000000000001
                i+=1
            num13=s1    
        elif raz==15:
            while i<l1:
                s1+=0.000000000000001
                i+=1
            num14=s1    
        if s==0:    
            k=19
        a=s;
if a==b:
    butun=1;num=num1=num2=num3=num4=num5=num6=num7=num8=num9=num10=num11=num12=num13=num14=0
nat=round(butun+num+num1+num2+num3+num4+num5+num6+num7+num8+num9+num10+num11+num12+num13+num14,15)
if i_a!=i_b:
    nat=0-nat
print(nat)
